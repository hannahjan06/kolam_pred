# %%
import numpy as np

# load the file
data_k = np.load("k_final.npy")

# check what’s inside
print(type(data))
print(data.shape)
print(data[:5])
# Out:
# <class 'numpy.ndarray'>
# (100, 50176)
# [[ 0  0  0 ...  0  0  0]
#  [61 55 60 ... 13 13 13]
#  [61 51 49 ... 23 22 22]
#  [ 0  0  1 ...  2  2  1]
#  [ 0  0  0 ...  0  0  0]]

# %%
import matplotlib.pyplot as plt

row = data[0]
img = row.reshape(224, 224)

plt.imshow(img, cmap="gray")
plt.axis("off")
plt.show()
